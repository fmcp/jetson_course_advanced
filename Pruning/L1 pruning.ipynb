# %% [markdown]
# # Setup

# %%
# !pip install tensorflow==2.3.2
# !pip install kerassurgeon
# !pip install keras==2.6.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.3.2
#   Downloading tensorflow-2.3.2-cp38-cp38-manylinux2010_x86_64.whl (320.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.5/320.5 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (3.19.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (1.15.0)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 78.6 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (1.51.1)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (1.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (1.6.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (0.38.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (2.2.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (2.9.1)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.0/459.0 KB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (1.1.2)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 71.2 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.3.2) (1.14.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (2.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.2) (2.25.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (5.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.2) (3.2.2)
# Installing collected packages: tensorflow-estimator, numpy, gast, h5py, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# xarray-einstats 0.4.0 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# tifffile 2022.10.10 requires numpy>=1.19.2, but you have numpy 1.18.5 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you have numpy 1.18.5 which is incompatible.
# plotnine 0.8.0 requires numpy>=1.19.0, but you have numpy 1.18.5 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# jax 0.3.25 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# cmdstanpy 1.0.8 requires numpy>=1.21, but you have numpy 1.18.5 which is incompatible.
# Successfully installed gast-0.3.3 h5py-2.10.0 numpy-1.18.5 tensorflow-2.3.2 tensorflow-estimator-2.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kerassurgeon
#   Downloading kerassurgeon-0.2.0-py3-none-any.whl (21 kB)
# Collecting importlib-metadata<2.0.0,>=1.7.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: keras[standalone-keras]<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from kerassurgeon) (2.9.0)
# Collecting pillow[examples]<8.0.0,>=7.2.0
#   Downloading Pillow-7.2.0-cp38-cp38-manylinux1_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from kerassurgeon) (2.3.2)
# Collecting pytest[test]<7.0.0,>=6.0.2
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 KB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas[examples]<2.0.0,>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from kerassurgeon) (1.3.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata<2.0.0,>=1.7.0->kerassurgeon) (3.11.0)
# WARNING: keras 2.9.0 does not provide the extra 'standalone-keras'
# WARNING: pandas 1.3.5 does not provide the extra 'examples'
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas[examples]<2.0.0,>=1.1.2->kerassurgeon) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas[examples]<2.0.0,>=1.1.2->kerassurgeon) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas[examples]<2.0.0,>=1.1.2->kerassurgeon) (1.18.5)
# WARNING: pillow 7.2.0 does not provide the extra 'examples'
# WARNING: pytest 6.2.5 does not provide the extra 'test'
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from pytest[test]<7.0.0,>=6.0.2->kerassurgeon) (21.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from pytest[test]<7.0.0,>=6.0.2->kerassurgeon) (22.2.0)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from pytest[test]<7.0.0,>=6.0.2->kerassurgeon) (0.10.2)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.8/dist-packages (from pytest[test]<7.0.0,>=6.0.2->kerassurgeon) (1.11.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (2.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (1.51.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (0.3.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (0.38.4)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (1.6.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (1.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (1.14.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3.0,>=2.0->kerassurgeon) (3.19.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (2.16.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->pytest[test]<7.0.0,>=6.0.2->kerassurgeon) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (5.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (1.3.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 KB 10.4 MB/s eta 0:00:00
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 11.0 MB/s eta 0:00:00
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 10.9 MB/s eta 0:00:00
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (2022.12.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<3.0,>=2.0->kerassurgeon) (3.2.2)
# Installing collected packages: pluggy, pillow, markdown, iniconfig, importlib-metadata, pytest, kerassurgeon
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.4.1
#     Uninstalling Markdown-3.4.1:
#       Successfully uninstalled Markdown-3.4.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.25.2 requires importlib-metadata>=4.8.0; python_version < "3.10", but you have importlib-metadata 1.7.0 which is incompatible.
# Successfully installed importlib-metadata-1.7.0 iniconfig-2.0.0 kerassurgeon-0.2.0 markdown-3.3.4 pillow-7.2.0 pluggy-1.0.0 pytest-6.2.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras==2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.2 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
# Successfully installed keras-2.6.0

# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import kerassurgeon
from kerassurgeon.operations import delete_channels

# %%
print(tf.__version__)
print(keras.__version__)
print(kerassurgeon.__version__)
# Out:
# 2.3.2
# 2.4.0
# 0.2.0

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Train model without pruning

# %% [markdown]
# Load MNIST dataset

# %%
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# Normalize the input image so that each pixel value is between 0 and 1.

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# Define the model architecture

# %%
input = keras.layers.Input(shape=(28, 28))
reshape = keras.layers.Reshape(target_shape=(28, 28, 1))(input)
conv_1= keras.layers.Conv2D(filters=12, kernel_size=(3, 3), activation='relu', name="conv_1")(reshape)
conv_2 = keras.layers.Conv2D(filters=12, kernel_size=(3, 3), activation='relu', name="conv_2")(conv_1)
maxpool = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv_2)
flatten = keras.layers.Flatten()(maxpool)
dense = keras.layers.Dense(10)(flatten)

model =tf.keras.Model(inputs=[input], outputs=[dense])

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 26, 26, 12)        120
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 24, 24, 12)        1308
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 12)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1728)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                17290
# =================================================================
# Total params: 18,718
# Trainable params: 18,718
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the digit classification model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(
  train_images,
  train_labels,
  epochs=2,
  validation_split=0.1,
)
# Out:
# Epoch 1/2
# 1688/1688 [==============================] - 42s 25ms/step - loss: 0.2205 - accuracy: 0.9347 - val_loss: 0.0821 - val_accuracy: 0.9790
# Epoch 2/2
# 1688/1688 [==============================] - 44s 26ms/step - loss: 0.0807 - accuracy: 0.9763 - val_loss: 0.0628 - val_accuracy: 0.9828

# %% [markdown]
# Evaluate baseline test accuracy (loss and accuracy)

# %%
model.evaluate(
    test_images, test_labels, verbose=0)
# Out:
# [0.0636981874704361, 0.9793000221252441]

# %%
tf.keras.models.save_model(model, "/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_2conv.h5", include_optimizer=False)

# %% [markdown]
# # Pruning weights L1 norm

# %% [markdown]
# Save layers name and weights

# %%
w_list = []
layer_name = []

for i in range(len(model.layers)): 
    if ('keras.layers.Conv3D' in model.layers[i]._keras_api_names[0]) or ('keras.layers.Conv2D' in model.layers[i]._keras_api_names[0]):
        print(model.layers[i]._keras_api_names[0])
        w = model.layers[i].get_weights()[0]
        w_list.append(w)
        layer_name.append(model.layers[i].name)
# Out:
# keras.layers.Conv2D
# keras.layers.Conv2D

# %% [markdown]
# Calculate L1-norm for every filter

# %%
values_total = []

for i in range(len(w_list)):
    weight = w_list[i]
    weight_dict = {}

    num_filters = len(weight[0, 0, 0, :])

    for j in range(num_filters):
        w_s = np.sum(abs(weight[:, :, :, j]))
        weight_dict[j] = w_s

    values = np.fromiter(weight_dict.values(), dtype=float)
    values_total = np.append(values_total, values)

    weights_dict_sort = sorted(weight_dict.items(), key=lambda k: k[1])
    print("L1 norm conv layer {}\n".format(i + 1), weights_dict_sort)
# Out:
# L1 norm conv layer 1
#  [(10, 0.87408555), (1, 1.2171497), (3, 1.3152757), (9, 1.6418724), (5, 1.6475912), (0, 1.6859784), (4, 1.6980257), (11, 1.8032663), (7, 1.8263495), (6, 1.9128357), (2, 1.929857), (8, 1.9926293)]
# L1 norm conv layer 2
#  [(5, 11.148841), (4, 11.300719), (9, 11.561567), (0, 11.581647), (8, 12.323187), (2, 12.93309), (6, 12.950718), (1, 16.540323), (7, 17.61103), (11, 18.019434), (10, 20.10907), (3, 20.629942)]

# %% [markdown]
# Clone model without pruning to preserve original model

# %%
model_filters= keras.models.clone_model(model)
model_filters.set_weights(model.get_weights())

# %% [markdown]
# Remove lower filters values according to a small percentile

# %%
values_total = np.sort(values_total)
valor_percentile = 50
percentile = np.percentile(values_total, valor_percentile)

counter = 0
deleted = 0

for i in range(len(model_filters.layers)): 
    if model_filters.layers[i].name in layer_name:
      weight = w_list[counter]
      num_filters = len(weight[0, 0, 0, :])

      for j in reversed(range(num_filters)):
          w_s = np.sum(abs(weight[:, :, :, j]))
          if w_s < percentile and model_filters.layers[i].output_shape[-1] > 1:
                model_filters = delete_channels(model_filters, model_filters.layers[i], np.array([j]))
                deleted = deleted + 1

      counter = counter + 1
      
print("Percentile value " + str(percentile))
print("{} Filters removed".format(deleted))
# Out:
# Deleting 1/12 channels from layer: conv_1
# Deleting 1/11 channels from layer: conv_1
# Deleting 1/10 channels from layer: conv_1
# Deleting 1/9 channels from layer: conv_1
# Deleting 1/8 channels from layer: conv_1
# Deleting 1/7 channels from layer: conv_1
# Deleting 1/6 channels from layer: conv_1
# Deleting 1/5 channels from layer: conv_1
# Deleting 1/4 channels from layer: conv_1
# Deleting 1/3 channels from layer: conv_1
# Deleting 1/2 channels from layer: conv_1
# Percentile value 6.5707350969314575
# 11 Filters removed

# %% [markdown]
# Pruned model

# %%
model_filters.summary()
# Out:
# Model: "functional_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 26, 26, 1)         10
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 24, 24, 12)        120
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 12)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1728)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                17290
# =================================================================
# Total params: 17,420
# Trainable params: 17,420
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Test accuracy pruned model

# %%
model_filters.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model_filters.evaluate(
    test_images, test_labels, verbose=0)
# Out:
# [1.843855619430542, 0.3375000059604645]

# %%
tf.keras.models.save_model(model_filters, "/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_2conv_pruned.h5", include_optimizer=False)

# %% [markdown]
# # Fine-tune pruned model

# %%
model_filters.fit(
  train_images,
  train_labels,
  epochs=2,
  validation_split=0.1,
)
# Out:
# Epoch 1/2
# 1688/1688 [==============================] - 30s 18ms/step - loss: 0.2377 - accuracy: 0.9323 - val_loss: 0.1111 - val_accuracy: 0.9698
# Epoch 2/2
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.1071 - accuracy: 0.9675 - val_loss: 0.0843 - val_accuracy: 0.9765

# %%
model_filters.evaluate(
    test_images, test_labels, verbose=0)
# Out:
# [0.08673708140850067, 0.9725000262260437]

# %%
tf.keras.models.save_model(model_filters, "/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_2conv_ft.h5", include_optimizer=False)
