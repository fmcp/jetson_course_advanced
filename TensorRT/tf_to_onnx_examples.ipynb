# %% [markdown]
# # From Tensorflow model to Keras saved model

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tensorflow as tf

# %%
from google.colab import drive
drive.mount("/content/gdrive")
model_path = '/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_0.8sparsity'
model = tf.keras.models.load_model('/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_0.8sparsity.h5')
# Out:
# Mounted at /content/gdrive
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
tf.saved_model.save(model, model_path)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %% [markdown]
# # From Keras saved model to ONNX

# %%
# !pip install onnx tf2onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 91.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 KB 50.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
# !python -m tf2onnx.convert --saved-model '/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_0.8sparsity' --output '/content/gdrive/MyDrive/Curso-Jetson/models/mnist_model_0.8sparsity.onnx'
# Out:
# /usr/lib/python3.8/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-01-24 09:57:30,757 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2023-01-24 09:57:30,931 - INFO - Signatures found in model: [serving_default].
# 2023-01-24 09:57:30,931 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2023-01-24 09:57:30,931 - INFO - Output names: ['dense']
# 2023-01-24 09:57:31,011 - INFO - Using tensorflow=2.9.2, onnx=1.13.0, tf2onnx=1.13.0/2c1db5
# 2023-01-24 09:57:31,012 - INFO - Using opset <onnx, 13>
# 2023-01-24 09:57:31,023 - INFO - Computed 0 values for constant folding
# 2023-01-24 09:57:31,041 - INFO - Optimizing ONNX model
# ...
