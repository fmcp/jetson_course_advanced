# %% [markdown]
# # From Tensorflow model to Keras saved model

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tensorflow as tf

# %%
model = tf.keras.applications.resnet.ResNet50()
# Out:
# ...
# 102967424/102967424 [==============================] - 6s 0us/step

# %%
from google.colab import drive
drive.mount("/content/gdrive")
keras_model_path = '/content/gdrive/MyDrive/Curso-Jetson/models/resnet50_keras_model'
# Out:
# Mounted at /content/gdrive

# %%
tf.saved_model.save(model, keras_model_path)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.

# %% [markdown]
# # From Keras saved model to ONNX

# %%
# !pip install onnx tf2onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 71.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 KB 37.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 60.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
# !python -m tf2onnx.convert --saved-model '/content/gdrive/MyDrive/Curso-Jetson/models/resnet50_keras_model' --output '/content/gdrive/MyDrive/Curso-Jetson/models/resnet50.onnx'
# Out:
# /usr/lib/python3.8/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-01-19 11:41:28,496 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2023-01-19 11:41:33,390 - INFO - Signatures found in model: [serving_default].
# 2023-01-19 11:41:33,390 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2023-01-19 11:41:33,392 - INFO - Output names: ['predictions']
# 2023-01-19 11:41:37,671 - INFO - Using tensorflow=2.9.2, onnx=1.13.0, tf2onnx=1.13.0/2c1db5
# 2023-01-19 11:41:37,671 - INFO - Using opset <onnx, 13>
# 2023-01-19 11:41:43,095 - INFO - Computed 0 values for constant folding
# 2023-01-19 11:41:46,784 - INFO - Optimizing ONNX model
# ...
